# %%
import yfinance as yf
from pandas_datareader import data as pdr
from ema_module import *
import warnings
import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = grab_portfolio_data(['TSLA', 'BOXL', 'AAPL'], '2010-01-01', end = datetime.date.today())
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
view_portfolio_history(df, "BOXL", 20, 100)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x12ba71d50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12be68290>)
